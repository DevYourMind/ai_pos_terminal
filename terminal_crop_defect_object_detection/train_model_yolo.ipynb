# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.193  Python-3.11.6 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24564MiB)
# Setup complete  (20 CPUs, 63.8 GB RAM, 525.7/930.7 GB disk)

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8m.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='data.yaml', epochs=150, imgsz=1280)  # train the model
# Out:
# New https://pypi.org/project/ultralytics/8.0.210 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.193  Python-3.11.6 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3090 Ti, 24564MiB)
# ...
